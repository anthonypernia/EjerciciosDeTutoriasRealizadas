# %%
import pandas as pd
import sqlalchemy as db
import requests
import json

# %%
engine = db.create_engine('sqlite:///datasets/nba_salary.sqlite')
connection = engine.connect()

# %%
dfStats = pd.read_sql_query("SELECT * FROM Seasons_Stats", connection)
dfSalary = pd.read_sql_query("SELECT * FROM NBA_season1718_salary", connection)

# %%
pd.read_sql_query("SELECT * FROM NBA_season1718_salary WHERE season17_18 > 10000000", connection)
# Out:
#         X1            Player   Tm  season17_18
# 0      1.0     Stephen Curry  GSW   34682550.0
# 1      2.0      LeBron James  CLE   33285709.0
# 2      3.0      Paul Millsap  DEN   31269231.0
# 3      4.0    Gordon Hayward  BOS   29727900.0
# 4      5.0     Blake Griffin  DET   29512900.0
# ..     ...               ...  ...          ...
# 117  118.0   Mirza Teletovic  MIL   10500000.0
# 118  119.0  Bojan Bogdanovic  IND   10500000.0
# 119  120.0         Jon Leuer  DET   10497319.0
# 120  121.0     Iman Shumpert  SAC   10337079.0
# 121  122.0  Maurice Harkless  POR   10162922.0
#
# [122 rows x 4 columns]

# %%
pd.read_sql_query("SELECT * FROM Seasons_Stats WHERE Year == 2017", connection)
# Out:
#           X1    Year             Player Pos   Age   Tm     G   GS      MP  \
# 0    24096.0  2017.0       Alex Abrines  SG  23.0  OKC  68.0  NaN  1055.0
# 1    24097.0  2017.0         Quincy Acy  PF  26.0  TOT  38.0  1.0   558.0
# 2    24098.0  2017.0         Quincy Acy  PF  26.0  DAL   6.0  0.0    48.0
# 3    24099.0  2017.0         Quincy Acy  PF  26.0  BRK  32.0  1.0   510.0
# 4    24100.0  2017.0       Steven Adams   C  23.0  OKC  80.0  NaN  2389.0
# ..       ...     ...                ...  ..   ...  ...   ...  ...     ...
# 590  24686.0  2017.0        Cody Zeller  PF  24.0  CHO  62.0  NaN  1725.0
# 591  24687.0  2017.0       Tyler Zeller   C  27.0  BOS  51.0  NaN   525.0
# 592  24688.0  2017.0  Stephen Zimmerman   C  20.0  ORL  19.0  0.0   108.0
# 593  24689.0  2017.0        Paul Zipser  SF  22.0  CHI  44.0  NaN   843.0
# 594  24690.0  2017.0        Ivica Zubac   C  19.0  LAL  38.0  NaN   609.0
#
#       PER  ...    FT%  ORB  DRB    TRB   AST  STL  BLK  TOV     PF    PTS
# ...

# %%
pd.read_sql_query("SELECT Year , ROUND(AST) AS PROM_AST, ROUND(PTS) AS PROM_PTS, ROUND(PF) AS PROM_PF FROM Seasons_Stats GROUP BY 1 ", connection)
# Out:
#       Year  PROM_AST  PROM_PTS  PROM_PF
# 0      NaN       NaN       NaN      NaN
# 1   1950.0     176.0     458.0    217.0
# 2   1951.0     138.0    1121.0    284.0
# 3   1952.0     170.0    1674.0    250.0
# 4   1953.0     154.0     661.0    203.0
# ..     ...       ...       ...      ...
# 64  2013.0      11.0     116.0     53.0
# 65  2014.0      28.0     171.0    122.0
# 66  2015.0      68.0     398.0    147.0
# 67  2016.0      27.0     307.0    103.0
# 68  2017.0      40.0     406.0    114.0
#
# [69 rows x 4 columns]

# %%
pd.read_sql_query("""SELECT 
                  A.Player AS PLAYER, 
                  ROUND(B.season17_18) AS PROM_SAL, 
                  ROUND(A.PTS) AS PROM_PTS 
                  FROM Seasons_Stats AS A 
                  INNER JOIN NBA_season1718_salary AS B 
                  ON A.Player=B.Player
                  GROUP BY 1""", connection)
# Out:
#               PLAYER    PROM_SAL  PROM_PTS
# 0       A.J. Hammons   1312611.0      48.0
# 1       Aaron Brooks   2116955.0     264.0
# 2       Aaron Gordon   5504420.0     243.0
# 3         Aaron Gray    452059.0     262.0
# 4         Al Horford  27734405.0     821.0
# ..               ...         ...       ...
# 441  Wilson Chandler  12016854.0     255.0
# 442     Yogi Ferrell   1312611.0     462.0
# 443      Zach LaVine   3202217.0     778.0
# 444    Zach Randolph  12307692.0     114.0
# 445    Zaza Pachulia   3477600.0     194.0
#
# [446 rows x 3 columns]

# %%
dfSalary.head(2)
# Out:
#     X1         Player   Tm  season17_18
# 0  1.0  Stephen Curry  GSW   34682550.0
# 1  2.0   LeBron James  CLE   33285709.0

# %%
dfStats.head(2)
# Out:
#     X1    Year           Player  Pos   Age   Tm     G  GS  MP  PER  ...  \
# 0  0.0  1950.0  Curly Armstrong  G-F  31.0  FTW  63.0 NaN NaN  NaN  ...
# 1  1.0  1950.0     Cliff Barker   SG  29.0  INO  49.0 NaN NaN  NaN  ...
#
#      FT%  ORB  DRB  TRB    AST  STL  BLK  TOV     PF    PTS
# 0  0.705  NaN  NaN  NaN  176.0  NaN  NaN  NaN  217.0  458.0
# 1  0.708  NaN  NaN  NaN  109.0  NaN  NaN  NaN   99.0  279.0
#
# [2 rows x 53 columns]

# %%
dfSalary.loc[dfSalary['season17_18'] > 10000000]
# Out:
#         X1            Player   Tm  season17_18
# 0      1.0     Stephen Curry  GSW   34682550.0
# 1      2.0      LeBron James  CLE   33285709.0
# 2      3.0      Paul Millsap  DEN   31269231.0
# 3      4.0    Gordon Hayward  BOS   29727900.0
# 4      5.0     Blake Griffin  DET   29512900.0
# ..     ...               ...  ...          ...
# 117  118.0   Mirza Teletovic  MIL   10500000.0
# 118  119.0  Bojan Bogdanovic  IND   10500000.0
# 119  120.0         Jon Leuer  DET   10497319.0
# 120  121.0     Iman Shumpert  SAC   10337079.0
# 121  122.0  Maurice Harkless  POR   10162922.0
#
# [122 rows x 4 columns]

# %%
#drop na in year
dfStats = dfStats.dropna(subset=['Year'])

# %%
dfStats['Year'] = pd.to_numeric(dfStats['Year'], errors='coerce')
dfStats = dfStats.dropna(subset=['Year'])
dfStats['Year'] = dfStats['Year'].astype(int)
# Out:
# /tmp/ipykernel_9235/3822591595.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfStats['Year'] = pd.to_numeric(dfStats['Year'], errors='coerce')

# %%
dfStats.loc[dfStats['Year'] == 2017]
# Out:
#             X1  Year             Player Pos   Age   Tm     G   GS      MP  \
# 24096  24096.0  2017       Alex Abrines  SG  23.0  OKC  68.0  NaN  1055.0
# 24097  24097.0  2017         Quincy Acy  PF  26.0  TOT  38.0  1.0   558.0
# 24098  24098.0  2017         Quincy Acy  PF  26.0  DAL   6.0  0.0    48.0
# 24099  24099.0  2017         Quincy Acy  PF  26.0  BRK  32.0  1.0   510.0
# 24100  24100.0  2017       Steven Adams   C  23.0  OKC  80.0  NaN  2389.0
# ...        ...   ...                ...  ..   ...  ...   ...  ...     ...
# 24686  24686.0  2017        Cody Zeller  PF  24.0  CHO  62.0  NaN  1725.0
# 24687  24687.0  2017       Tyler Zeller   C  27.0  BOS  51.0  NaN   525.0
# 24688  24688.0  2017  Stephen Zimmerman   C  20.0  ORL  19.0  0.0   108.0
# 24689  24689.0  2017        Paul Zipser  SF  22.0  CHI  44.0  NaN   843.0
# 24690  24690.0  2017        Ivica Zubac   C  19.0  LAL  38.0  NaN   609.0
#
#         PER  ...    FT%  ORB  DRB    TRB   AST  STL  BLK  TOV     PF    PTS
# ...

# %%
dfStats.dtypes
# Out:
# X1        float64
# Year      float64
# Player     object
# Pos        object
# Age       float64
# Tm         object
# G         float64
# GS        float64
# MP        float64
# PER       float64
# TS%       float64
# 3PAr      float64
# FTr       float64
# ORB%      float64
# DRB%      float64
# TRB%      float64
# AST%      float64
# STL%      float64
# BLK%      float64
# TOV%      float64
# USG%      float64
# blanl      object
# OWS       float64
# DWS       float64
# WS        float64
# WS/48     float64
# blank2     object
# OBPM      float64
# DBPM      float64
# BPM       float64
# VORP      float64
# FG        float64
# FGA       float64
# FG%       float64
# 3P        float64
# 3PA       float64
# 3P%       float64
# 2P        float64
# 2PA       float64
# 2P%       float64
# eFG%      float64
# FT        float64
# FTA       float64
# FT%       float64
# ORB       float64
# DRB       float64
# TRB       float64
# AST       float64
# STL       float64
# BLK       float64
# ...

# %%
dfStats.groupby('Year').mean()
# Out:
#            X1        Age          G        GS           MP        PER  \
# Year
# 1950    155.5  26.131410  42.884615       NaN          NaN        NaN
# 1951    399.5  26.344828  43.890805       NaN          NaN        NaN
# 1952    552.5  26.130769  49.415385       NaN  1294.792308  12.511811
# 1953    698.5  26.018868  45.725000       NaN  1201.581250  11.698742
# 1954    845.0  25.769231  49.862595       NaN  1278.458015  11.893798
# ...       ...        ...        ...       ...          ...        ...
# 2013  21965.0  26.535777  49.219895  0.170854  1112.923211  12.127972
# 2014  22558.0  26.472995  46.780687  0.168103  1066.883797  12.200818
# 2015  23190.0  26.500768  45.960061  0.204444  1041.775730  12.549155
# 2016  23805.5  26.823529  49.162630  0.226519  1104.809689  13.218166
# 2017  24393.0  26.406723  48.433613  0.189320  1090.680672  12.728571
#
#            TS%      3PAr       FTr      ORB%  ...       FT%       ORB  \
# ...

# %%
dfStats.groupby('Year')['PTS','AST', 'PF'].mean()
# Out:
# /tmp/ipykernel_9235/812381187.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   dfStats.groupby('Year')['PTS','AST', 'PF'].mean()
#              PTS         AST          PF
# Year
# 1950  331.929487   81.717949  114.990385
# 1951  375.505747   93.051724  123.494253
# 1952  446.892308  116.038462  144.523077
# 1953  402.225000  102.306250  142.218750
# 1954  421.770992  106.961832  136.015267
# ...          ...         ...         ...
# 2013  448.427574  102.178010   91.418848
# 2014  441.872340   97.070376   91.238953
# 2015  428.067588   95.960061   87.199693
# 2016  465.636678  102.384083   92.674740
# 2017  474.732773  101.053782   90.226891
#
# [68 rows x 3 columns]

# %%
url1 = 'http://192.168.0.16:3000/data'
url2 = 'http://192.168.0.16:3000/data_multiline'

# %%
response = requests.get(url1)

# %%
response.text
# Out:
# '[{"id":1,"name":"John","age":20},{"id":2,"name":"Jane","age":21},{"id":3,"name":"Jack","age":22}]'

# %%
jsondata = json.loads(response.text)

# %%
json.loads(response.text)
# Out:
# [{'id': 1, 'name': 'John', 'age': 20},
#  {'id': 2, 'name': 'Jane', 'age': 21},
#  {'id': 3, 'name': 'Jack', 'age': 22}]

# %%
pd.DataFrame(jsondata)
# Out:
#    id  name  age
# 0   1  John   20
# 1   2  Jane   21
# 2   3  Jack   22

# %%
pd.DataFrame.from_dict(jsondata)
# Out:
#    id  name  age
# 0   1  John   20
# 1   2  Jane   21
# 2   3  Jack   22

# %%
response = requests.get(url2)

# %%
response.text
# Out:
# '[{"id":1,"name":"John","age":20,"address":{"street":"123 Main St","city":"Anytown","state":"CA"}},{"id":2,"name":"Jane","age":21,"address":{"street":"Street 1","city":"City 1","state":"State 1"}},{"id":3,"name":"Jack","age":22,"address":{"street":"Street 2","city":"City 2","state":"State 2"}}]'

# %%
jsondata = json.loads(response.text)

# %%
json.loads(response.text)
# Out:
# [{'id': 1,
#   'name': 'John',
#   'age': 20,
#   'address': {'street': '123 Main St', 'city': 'Anytown', 'state': 'CA'}},
#  {'id': 2,
#   'name': 'Jane',
#   'age': 21,
#   'address': {'street': 'Street 1', 'city': 'City 1', 'state': 'State 1'}},
#  {'id': 3,
#   'name': 'Jack',
#   'age': 22,
#   'address': {'street': 'Street 2', 'city': 'City 2', 'state': 'State 2'}}]

# %%
df2 = pd.DataFrame(jsondata)
df2
# Out:
#    id  name  age                                            address
# 0   1  John   20  {'street': '123 Main St', 'city': 'Anytown', '...
# 1   2  Jane   21  {'street': 'Street 1', 'city': 'City 1', 'stat...
# 2   3  Jack   22  {'street': 'Street 2', 'city': 'City 2', 'stat...

# %%
df2 = pd.json_normalize(jsondata)
df2
# Out:
#    id  name  age address.street address.city address.state
# 0   1  John   20    123 Main St      Anytown            CA
# 1   2  Jane   21       Street 1       City 1       State 1
# 2   3  Jack   22       Street 2       City 2       State 2

# %%
df2['address.street']
# Out:
# 0    123 Main St
# 1       Street 1
# 2       Street 2
# Name: address.street, dtype: object
