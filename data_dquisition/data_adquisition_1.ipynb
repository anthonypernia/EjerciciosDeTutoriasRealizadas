# %%
import pandas as pd

# %%
df = pd.read_csv('./datasets/data.csv')
df
# Out:
#       Age|Sex|ID|Race|Country|Education|Education-Num|Marital Status|Relationship
# 0      39.0| Male|49084| White| United-States| Bachel...
# 1      50.0| Male|68553| White| United-States| Bachel...
# 2      38.0| Male|143654| White| United-States| HS-gr...
# 3      53.0| Male|41510| Black| United-States| 11th|7...
# 4      28.0| Female|195025| Black| Cuba| Bachelors|13...
# ...                                                  ...
# 48838  39.0| Female|735617153| White| United-States| ...
# 48839  64.0| Male|1131807446| Black| United-States| H...
# 48840  38.0| Male|781422087| White| United-States| Ba...
# 48841  44.0| Male|161771296| Asian-Pac-Islander| Unit...
# 48842  35.0| Male|1344995623| White| United-States| B...
#
# [48843 rows x 1 columns]

# %%
df = pd.read_csv('./datasets/data.csv', sep='|')
df
# Out:
#         Age      Sex          ID                 Race         Country  \
# 0      39.0     Male       49084                White   United-States
# 1      50.0     Male       68553                White   United-States
# 2      38.0     Male      143654                White   United-States
# 3      53.0     Male       41510                Black   United-States
# 4      28.0   Female      195025                Black            Cuba
# ...     ...      ...         ...                  ...             ...
# 48838  39.0   Female   735617153                White   United-States
# 48839  64.0     Male  1131807446                Black   United-States
# 48840  38.0     Male   781422087                White   United-States
# 48841  44.0     Male   161771296   Asian-Pac-Islander   United-States
# 48842  35.0     Male  1344995623                White   United-States
#
#         Education  Education-Num       Marital Status     Relationship
# ...

# %%
df = pd.read_csv('./datasets/encuesta.txt', delim_whitespace=True)
df
# Out:
#                                   ID  asistio  Tarea  Comportamiento Pago
# 0    cef3615d61b202f1dc794ef2746df14        1    1.0             0.0   si
# 1    323e5a13644d18185c743c241407754        0    0.0             NaN   no
# 2    b29a107e5cd062e654a63764157461d        0    0.0             NaN   no
# 3   04a11e4bcb573a1261eb0d9948d32637        1    0.0             0.0   si
# 4    9368291c3d5d5f5c8cdb1a575e18bec        1    0.0             0.0   si
# 5    dd0e77eab270e4b67c19b0d6bbf621b        0    0.0             NaN   no
# 6    7599c0aa419b59fd11ffede98a3665d        0    0.0             NaN   si
# 7    6dff182b452487f07a47596f314bddc        0    1.0             NaN   si
# 8    9dc233fed1c6eb2432672ab4bb39249        0    0.0             NaN   no
# 9   265fa78a1fb2409ff5416aec3c4f950d        1    0.0             0.0   si
# 10  3b461f95fe50be35b927c255b3f7dc3a        1    1.0             1.0   no
# 11  e786f1288887afb309eb913d28ffd6b0        1    0.0             0.0   si
# ...

# %%
df = pd.read_csv('./datasets/encuesta.txt', delim_whitespace=True, true_values = ['si'], false_values= ['no'])
df.head(10)
# Out:
#                                  ID  asistio  Tarea  Comportamiento   Pago
# 0   cef3615d61b202f1dc794ef2746df14        1    1.0             0.0   True
# 1   323e5a13644d18185c743c241407754        0    0.0             NaN  False
# 2   b29a107e5cd062e654a63764157461d        0    0.0             NaN  False
# 3  04a11e4bcb573a1261eb0d9948d32637        1    0.0             0.0   True
# 4   9368291c3d5d5f5c8cdb1a575e18bec        1    0.0             0.0   True
# 5   dd0e77eab270e4b67c19b0d6bbf621b        0    0.0             NaN  False
# 6   7599c0aa419b59fd11ffede98a3665d        0    0.0             NaN   True
# 7   6dff182b452487f07a47596f314bddc        0    1.0             NaN   True
# 8   9dc233fed1c6eb2432672ab4bb39249        0    0.0             NaN  False
# 9  265fa78a1fb2409ff5416aec3c4f950d        1    0.0             0.0   True

# %%
df = pd.read_csv('./datasets/encuesta.txt', delim_whitespace=True, true_values = ['si'], false_values= ['no'])
df
# Out:
#                                   ID  asistio  Tarea  Comportamiento   Pago
# 0    cef3615d61b202f1dc794ef2746df14        1    1.0             0.0   True
# 1    323e5a13644d18185c743c241407754        0    0.0             NaN  False
# 2    b29a107e5cd062e654a63764157461d        0    0.0             NaN  False
# 3   04a11e4bcb573a1261eb0d9948d32637        1    0.0             0.0   True
# 4    9368291c3d5d5f5c8cdb1a575e18bec        1    0.0             0.0   True
# 5    dd0e77eab270e4b67c19b0d6bbf621b        0    0.0             NaN  False
# 6    7599c0aa419b59fd11ffede98a3665d        0    0.0             NaN   True
# 7    6dff182b452487f07a47596f314bddc        0    1.0             NaN   True
# 8    9dc233fed1c6eb2432672ab4bb39249        0    0.0             NaN  False
# 9   265fa78a1fb2409ff5416aec3c4f950d        1    0.0             0.0   True
# 10  3b461f95fe50be35b927c255b3f7dc3a        1    1.0             1.0  False
# ...

# %%
#transform
df['Tarea'] = df['Tarea'].astype(bool)
df['asistio'] = df['asistio'].astype(bool)

df.head()
# Out:
#                                  ID  asistio  Tarea  Comportamiento   Pago
# 0   cef3615d61b202f1dc794ef2746df14     True   True             0.0   True
# 1   323e5a13644d18185c743c241407754    False  False             NaN  False
# 2   b29a107e5cd062e654a63764157461d    False  False             NaN  False
# 3  04a11e4bcb573a1261eb0d9948d32637     True  False             0.0   True
# 4   9368291c3d5d5f5c8cdb1a575e18bec     True  False             0.0   True

# %%
#put 0 in NaN
df['Comportamiento'] = df['Comportamiento'].fillna(0)
df.head()
# Out:
#                                  ID  asistio  Tarea  Comportamiento   Pago
# 0   cef3615d61b202f1dc794ef2746df14     True   True             0.0   True
# 1   323e5a13644d18185c743c241407754    False  False             0.0  False
# 2   b29a107e5cd062e654a63764157461d    False  False             0.0  False
# 3  04a11e4bcb573a1261eb0d9948d32637     True  False             0.0   True
# 4   9368291c3d5d5f5c8cdb1a575e18bec     True  False             0.0   True

# %%
df = pd.read_csv('./datasets/encuesta.txt', delim_whitespace=True, true_values = ['si'], false_values= ['no'], dtype={'Tarea': bool, 'asistio': bool })
df.head(2)
# Out:
#                                 ID  asistio  Tarea  Comportamiento   Pago
# 0  cef3615d61b202f1dc794ef2746df14     True   True             0.0   True
# 1  323e5a13644d18185c743c241407754    False  False             NaN  False

# %%
df = pd.read_csv('./datasets/encuesta.txt', delim_whitespace=True, true_values = ['si'], false_values= ['no'], dtype={'Tarea': bool, 'asistio': bool}).fillna(0)
df.head(2)
# Out:
#                                 ID  asistio  Tarea  Comportamiento   Pago
# 0  cef3615d61b202f1dc794ef2746df14     True   True             0.0   True
# 1  323e5a13644d18185c743c241407754    False  False             0.0  False

# %%
df = pd.read_csv('./datasets/encuesta.txt', sep=' ')
df.head(2)
# Out:
#                         Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  \
# 0  cef3615d61b202f1dc794ef2746df14         NaN         NaN         NaN
# 1  323e5a13644d18185c743c241407754         NaN         NaN         NaN
#
#    Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# 0         NaN         NaN         NaN         NaN         1.0         NaN
# 1         NaN         NaN         NaN         NaN         0.0         NaN
#
#    ...  Unnamed: 137  Unnamed: 138  Unnamed: 139  Unnamed: 140  Unnamed: 141  \
# 0  ...           NaN           NaN           NaN           NaN           NaN
# 1  ...           NaN           NaN           NaN           NaN           NaN
#
#    Unnamed: 142  Unnamed: 143  Unnamed: 144  Unnamed: 145  Unnamed: 146
# 0           NaN           NaN           NaN           NaN           NaN
# 1           NaN           NaN           NaN           NaN           NaN
#
# [2 rows x 147 columns]

# %%
df = pd.read_csv('./datasets/data.csv', sep='|')
df.head(2)
# Out:
#     Age    Sex     ID    Race         Country   Education  Education-Num  \
# 0  39.0   Male  49084   White   United-States   Bachelors           13.0
# 1  50.0   Male  68553   White   United-States   Bachelors           13.0
#
#         Marital Status    Relationship
# 0        Never-married   Not-in-family
# 1   Married-civ-spouse         Husband

# %%
def replace_algo(text):
    if text.lower() == 'Male':
        return 'Male-----'
    else:
        return 'Woman-----'

# %%
df['Sex'] = df['Sex'].str.replace('Male','Male---____reyryywyywyewy')
df.head(2)
# Out:
#     Age                                Sex     ID    Race         Country  \
# 0  39.0   Male---____reyryywyywyewy-------  49084   White   United-States
# 1  50.0   Male---____reyryywyywyewy-------  68553   White   United-States
#
#     Education  Education-Num       Marital Status    Relationship
# 0   Bachelors           13.0        Never-married   Not-in-family
# 1   Bachelors           13.0   Married-civ-spouse         Husband

# %%
df = pd.read_excel('./datasets/data.xlsx')
df
# Out:
#         Age      Sex          ID                 Race         Country  \
# 0      39.0     Male       49084                White   United-States
# 1      50.0     Male       68553                White   United-States
# 2      38.0     Male      143654                White   United-States
# 3      53.0     Male       41510                Black   United-States
# 4      28.0   Female      195025                Black            Cuba
# ...     ...      ...         ...                  ...             ...
# 48838  39.0   Female   735617153                White   United-States
# 48839  64.0     Male  1131807446                Black   United-States
# 48840  38.0     Male   781422087                White   United-States
# 48841  44.0     Male   161771296   Asian-Pac-Islander   United-States
# 48842  35.0     Male  1344995623                White   United-States
#
#         Education  Education-Num       Marital Status     Relationship
# ...

# %%
df = pd.read_excel('./datasets/data.xlsx', sheet_name='Sheet1')
df
# Out:
#         Age      Sex          ID                 Race         Country  \
# 0      39.0     Male       49084                White   United-States
# 1      50.0     Male       68553                White   United-States
# 2      38.0     Male      143654                White   United-States
# 3      53.0     Male       41510                Black   United-States
# 4      28.0   Female      195025                Black            Cuba
# ...     ...      ...         ...                  ...             ...
# 48838  39.0   Female   735617153                White   United-States
# 48839  64.0     Male  1131807446                Black   United-States
# 48840  38.0     Male   781422087                White   United-States
# 48841  44.0     Male   161771296   Asian-Pac-Islander   United-States
# 48842  35.0     Male  1344995623                White   United-States
#
#         Education  Education-Num       Marital Status     Relationship
# ...

# %%
df = pd.read_excel('./datasets/data.xlsx', sheet_name='Sheet1', usecols='A:C')
df
# Out:
#         Age      Sex          ID
# 0      39.0     Male       49084
# 1      50.0     Male       68553
# 2      38.0     Male      143654
# 3      53.0     Male       41510
# 4      28.0   Female      195025
# ...     ...      ...         ...
# 48838  39.0   Female   735617153
# 48839  64.0     Male  1131807446
# 48840  38.0     Male   781422087
# 48841  44.0     Male   161771296
# 48842  35.0     Male  1344995623
#
# [48843 rows x 3 columns]

# %%
df = pd.read_excel('./datasets/data.xlsx', sheet_name='Sheet1', usecols='A:C, H')
df
# Out:
#         Age      Sex          ID       Marital Status
# 0      39.0     Male       49084        Never-married
# 1      50.0     Male       68553   Married-civ-spouse
# 2      38.0     Male      143654             Divorced
# 3      53.0     Male       41510   Married-civ-spouse
# 4      28.0   Female      195025   Married-civ-spouse
# ...     ...      ...         ...                  ...
# 48838  39.0   Female   735617153             Divorced
# 48839  64.0     Male  1131807446              Widowed
# 48840  38.0     Male   781422087   Married-civ-spouse
# 48841  44.0     Male   161771296             Divorced
# 48842  35.0     Male  1344995623   Married-civ-spouse
#
# [48843 rows x 4 columns]

# %%
#reading pkl files
df.to_pickle('./datasets/data_ex.pkl')

# %%
df = pd.read_pickle('./datasets/data_ex.pkl')
df
# Out:
#         Age      Sex          ID       Marital Status
# 0      39.0     Male       49084        Never-married
# 1      50.0     Male       68553   Married-civ-spouse
# 2      38.0     Male      143654             Divorced
# 3      53.0     Male       41510   Married-civ-spouse
# 4      28.0   Female      195025   Married-civ-spouse
# ...     ...      ...         ...                  ...
# 48838  39.0   Female   735617153             Divorced
# 48839  64.0     Male  1131807446              Widowed
# 48840  38.0     Male   781422087   Married-civ-spouse
# 48841  44.0     Male   161771296             Divorced
# 48842  35.0     Male  1344995623   Married-civ-spouse
#
# [48843 rows x 4 columns]

# %%
df = pd.read_pickle('./datasets/data.pkl', compression='gzip')
df
# Out:
#         Age      Sex          ID                 Race         Country  \
# 0      39.0     Male       49084                White   United-States
# 1      50.0     Male       68553                White   United-States
# 2      38.0     Male      143654                White   United-States
# 3      53.0     Male       41510                Black   United-States
# 4      28.0   Female      195025                Black            Cuba
# ...     ...      ...         ...                  ...             ...
# 48838  39.0   Female   735617153                White   United-States
# 48839  64.0     Male  1131807446                Black   United-States
# 48840  38.0     Male   781422087                White   United-States
# 48841  44.0     Male   161771296   Asian-Pac-Islander   United-States
# 48842  35.0     Male  1344995623                White   United-States
#
#         Education  Education-Num       Marital Status     Relationship
# ...
